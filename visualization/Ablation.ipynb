# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("ablation_cross.csv")
df1
# Out:
#     Pred Len    MSE  Epoch  Cross Attention
# 0         96  0.384      6             True
# 1         96  0.376      5             True
# 2         96  0.380      4             True
# 3        192  0.424      6             True
# 4        192  0.409      4             True
# 5        192  0.415      6             True
# 6        336  0.454      5             True
# 7        336  0.438      5             True
# 8        336  0.464      5             True
# 9        720  0.460      5             True
# 10       720  0.494      5             True
# 11       720  0.450      6             True
# 12        96  0.375      9            False
# 13        96  0.390     10            False
# 14        96  0.380      6            False
# 15       192  0.416      9            False
# 16       192  0.412     10            False
# 17       192  0.411     10            False
# 18       336  0.435      9            False
# 19       336  0.433     10            False
# ...

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(6, 6))
plot2 = sns.lineplot(data=df1, x="Pred Len", y="MSE", hue="Cross Attention", markers=True, style="Cross Attention", style_order=[True, False], ax=axes[0])
plot2 = sns.lineplot(data=df1, x="Pred Len", y="Epoch", hue="Cross Attention", markers=True, style="Cross Attention", style_order=[True, False], ax=axes[1])
#sns.lineplot(data=df1, x="Pred Len", y="With Cross Attention", markers=True)
plt.savefig("ablation_cross_att.pdf", format="pdf", bbox_inches="tight")

# %%
df2 = pd.read_csv("ablation_patch.csv")
df2
# Out:
#     Patch Size    MSE
# 0            1  0.732
# 1            1  0.751
# 2            1  0.741
# 3           16  0.389
# 4           16  0.393
# 5           16  0.388
# 6           32  0.375
# 7           32  0.380
# 8           32  0.372
# 9           48  0.372
# 10          48  0.371
# 11          48  0.370
# 12          96  0.384
# 13          96  0.376
# 14          96  0.380

# %%
plt.figure(figsize=(6, 2))
sns.lineplot(data=df2, x="Patch Size", y="MSE", marker="o")
plt.savefig("ablation_patch.pdf", format="pdf", bbox_inches="tight")
